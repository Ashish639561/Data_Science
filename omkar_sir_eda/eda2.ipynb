# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa=pd.read_csv('Visadataset.csv')
visa
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $Shape$
# - will give number of rows and columns in tuple format

# %%
visa.shape
# Out:
# (25480, 12)

# %%
type(visa)
# Out:
# pandas.core.frame.DataFrame

# %%
print('the number of rows in visa dataset:',visa.shape[0])
print('the number of columns in visa dataset:',visa.shape[1])
# Out:
# the number of rows in visa dataset: 25480
# the number of columns in visa dataset: 12

# %% [markdown]
# visa.shape()
# - Functions are used to call
# - Functions means ()
# - not callable means,remove the brackets

# %% [markdown]
# $Size$
# - means number of rows * number of columns

# %%
visa.size
# Out:
# 305760

# %%
type(visa.size)
# Out:
# int

# %%
visa.shape[0] * visa.shape[1]
# Out:
# 305760

# %% [markdown]
# $Columns$
# - it will give list of columns in that dataset

# %%
print(visa.columns)
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
visa.columns.to_list()
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %% [markdown]
# $Index$
# - it will give range of index

# %%
print(visa.index)
# Out:
# RangeIndex(start=0, stop=25480, step=1)

# %%
type(visa.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %% [markdown]
# $Keys$
#
# - it will give all keys

# %%
visa.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa.to_dict().keys()
# Out:
# dict_keys(['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'no_of_employees', 'yr_of_estab', 'region_of_employment', 'prevailing_wage', 'unit_of_wage', 'full_time_position', 'case_status'])

# %%
visa.keys().to_list()
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %% [markdown]
# - list()-->to_list()
# - dict()-->to_dict()

# %% [markdown]
# $dtypes$
# - objects means Categorical data
# - int64 and float64

# %%
visa.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa.dtypes)
# Out:
# pandas.core.series.Series

# %%
visa.dtypes.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
visa.values
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       dtype=object)

# %%
type(visa.values)
# Out:
# numpy.ndarray

# %% [markdown]
# create 2 list from visa.dtypes
# - one categorical
# - one numerical

# %%
a = visa.dtypes.to_dict()
a
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
a = dict(visa.dtypes)
a
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
a['case_id']
# Out:
# dtype('O')

# %%
categorical_list=[]
numerical_list=[]
for key in a:
    if a[key] =='object':
        categorical_list.append(key)
    else:
        numerical_list.append(key)
print(categorical_list)
print(numerical_list)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# $head$
# - will give first 5 rows

# %%
visa.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %% [markdown]
# $tail$
# - will give last 5 values

# %%
visa.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa.tail(10)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25470                     N             2272         1970
# ...

# %% [markdown]
# $take$
# - will give middle data
# - from where you want

# %%
l=[100,200,300]
visa.take(l)#here axis=0 bydefault,if we give axis=1 so there is only 12 columns and we are providing more then 12,will generate indexerror
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa.take([300,400,500])#here axis=0,means row so that number is theres so no errors came here
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 300  EZYV301      Asia              Master's                  Y
# 400  EZYV401    Europe            Bachelor's                  Y
# 500  EZYV501      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 300                     N             3268         2012              Midwest
# 400                     N              714         1873                 West
# 500                     N             1245         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 300        101371.21         Year                  Y   Certified
# 400        113927.99         Week                  Y   Certified
# 500         92549.52         Year                  N   Certified

# %% [markdown]
# _task_
# * i want 150,300,450,rows from columns 5,8,12 means 4,7,11 because in python index starts from 0
# * and we know that axis=0 means row and axis=1 means columns

# %%
visa.take([150,300,450]).take([4,7,11],axis=1)
# Out:
#     requires_job_training region_of_employment case_status
# 150                     N                 West      Denied
# 300                     N              Midwest   Certified
# 450                     Y                 West      Denied

# %% [markdown]
# **iloc-loc**

# %% [markdown]
# * visa.iloc[<rows>,<columns>]
# * visa.iloc[start:end,start:end]

# %%
visa.iloc[100:150]#it will give columns also,if we don't give columns too
# Out:
#      case_id      continent education_of_employee has_job_experience  \
# 100  EZYV101           Asia              Master's                  Y
# 101  EZYV102           Asia              Master's                  Y
# 102  EZYV103           Asia            Bachelor's                  Y
# 103  EZYV104           Asia             Doctorate                  Y
# 104  EZYV105           Asia              Master's                  Y
# 105  EZYV106  North America             Doctorate                  Y
# 106  EZYV107           Asia            Bachelor's                  N
# 107  EZYV108           Asia            Bachelor's                  Y
# 108  EZYV109           Asia            Bachelor's                  N
# 109  EZYV110           Asia            Bachelor's                  Y
# 110  EZYV111  North America           High School                  Y
# 111  EZYV112           Asia              Master's                  Y
# 112  EZYV113           Asia            Bachelor's                  Y
# ...

# %%
visa.iloc[50:55,2:6]#means 50 to 54 rows and 2 to 5 columns
# Out:
#    education_of_employee has_job_experience requires_job_training  \
# 50            Bachelor's                  N                     N
# 51              Master's                  Y                     N
# 52            Bachelor's                  N                     N
# 53           High School                  Y                     N
# 54              Master's                  Y                     N
#
#     no_of_employees
# 50              746
# 51             3129
# 52             1647
# 53             2438
# 54            11733

# %%
visa.iloc[[150,300,450],[4,7,11]]#it works like also this
# Out:
#     requires_job_training region_of_employment case_status
# 150                     N                 West      Denied
# 300                     N              Midwest   Certified
# 450                     Y                 West      Denied

# %%
visa.iloc[[100,200,300],'case_status']
#it will genearte error,iloc will take only numbers
#so we will o for loc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\LENOVO\miniconda3\envs\new_env\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File c:\Users\LENOVO\miniconda3\envs\new_env\Lib\site-packages\pandas\core\indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ...

# %%
type(visa.iloc[[100,200,300],'case_status'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\LENOVO\miniconda3\envs\python_bases\Lib\site-packages\pandas\core\indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File c:\Users\LENOVO\miniconda3\envs\python_bases\Lib\site-packages\pandas\core\indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ...

# %%
visa.loc[[100,200,300],'case_status']
# Out:
# 100    Certified
# 200    Certified
# 300    Certified
# Name: case_status, dtype: object

# %%
type(visa.loc[[100,200,300],'case_status'])
# Out:
# pandas.core.series.Series

# %%
visa.loc[[100,200,300],['case_status']]
# Out:
#     case_status
# 100   Certified
# 200   Certified
# 300   Certified

# %%
visa.loc[[100,200,300],['case_status','continent']]
# Out:
#     case_status continent
# 100   Certified      Asia
# 200   Certified      Asia
# 300   Certified      Asia

# %% [markdown]
# __important__
# * take
# * iloc
# * loc

# %%
len(visa)
# Out:
# 25480

# %% [markdown]
# _isnull_
# *  to check is ther any missing values are there or not
# * is null you are asking an to pandas :True/False
# * if any missing values are there it will give True
# * if there is no missing values it will give False

# %%
visa.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# _info_

# %%
visa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
visa.describe()#it will not include categorical data
# Out:
#        case_id continent education_of_employee has_job_experience  \
# count    25480     25480                 25480              25480
# unique   25480         6                     4                  2
# top     EZYV01      Asia            Bachelor's                  Y
# freq         1     16861                 10234              14802
# mean       NaN       NaN                   NaN                NaN
# std        NaN       NaN                   NaN                NaN
# min        NaN       NaN                   NaN                NaN
# 25%        NaN       NaN                   NaN                NaN
# 50%        NaN       NaN                   NaN                NaN
# 75%        NaN       NaN                   NaN                NaN
# max        NaN       NaN                   NaN                NaN
#
#        requires_job_training  no_of_employees   yr_of_estab  \
# count                  25480     25480.000000  25480.000000
# ...

# %%
visa.describe(include='all')#it will include categorical data
# Out:
#        case_id continent education_of_employee has_job_experience  \
# count    25480     25480                 25480              25480
# unique   25480         6                     4                  2
# top     EZYV01      Asia            Bachelor's                  Y
# freq         1     16861                 10234              14802
# mean       NaN       NaN                   NaN                NaN
# std        NaN       NaN                   NaN                NaN
# min        NaN       NaN                   NaN                NaN
# 25%        NaN       NaN                   NaN                NaN
# 50%        NaN       NaN                   NaN                NaN
# 75%        NaN       NaN                   NaN                NaN
# max        NaN       NaN                   NaN                NaN
#
#        requires_job_training  no_of_employees   yr_of_estab  \
# count                  25480     25480.000000  25480.000000
# ...
